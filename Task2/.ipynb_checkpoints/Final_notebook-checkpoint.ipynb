# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# %%
train=pd.read_csv('dataset/train_set.csv')
test=pd.read_csv('dataset/test_set.csv')

# %%
train_=train.drop(columns=['ID','CLASS'])
test_=test.drop(columns=['ID','CLASS'])

# %%
# Handle Negative values 
# List of columns with negative values
negative_columns = train_.columns[(train_ < 0).any()].tolist()

#print("Columns with negative values:", negative_columns)
# Count of negative values for each column
neg_counts = train_[negative_columns].apply(lambda x: (x < 0).sum())

print("Number of negative values in each column:")
print(neg_counts)
# Out:
# Number of negative values in each column:
# Feature_27       55
# Feature_54       55
# Feature_55       14
# Feature_56       14
# Feature_57       55
#                ...
# Feature_2081     25
# Feature_2083    298
# Feature_2103      4
# Feature_2106      4
# Feature_2108    178
# Length: 93, dtype: int64

# %%
unique_counts=train.nunique()

# %%
# print("\n--- First 10 columns ---")
# print(unique_counts.head(10))

# # Print the last few results
# print("\n--- Last 10 columns ---")
# print(unique_counts.tail(10))

# # Print results sorted by unique count (useful to find constant or high cardinality columns)
# print("\n--- Columns sorted by unique count (fewest unique) ---")
# print(unique_counts.sort_values().head(10))

# print("\n--- Columns sorted by unique count (most unique) ---")
# print(unique_counts.sort_values(ascending=False).head(10))

# # Get summary statistics of the unique counts distribution
# print("\n--- Summary statistics of unique counts across all columns ---")
# print(unique_counts.describe())

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Columns: 3240 entries, ID to CLASS
# dtypes: float64(3238), int64(1), object(1)
# memory usage: 7.8+ MB

# %%
train["CLASS"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='CLASS'>

# %%
train["CLASS"].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
train.dtypes
# Out:
# ID               object
# Feature_1       float64
# Feature_2       float64
# Feature_3       float64
# Feature_4       float64
#                  ...
# Feature_3235    float64
# Feature_3236    float64
# Feature_3237    float64
# Feature_3238    float64
# CLASS             int64
# Length: 3240, dtype: object

# %%
import pandas as pd # Assuming df is a pandas DataFrame

def get_similar_value_cols(df, percent=90):
    """
    Finds columns where one value constitutes more than 'percent' of the data.
    Excludes columns with 2 or fewer unique values (like binary or constant columns).

    :param df: input data in the form of a dataframe (pandas DataFrame).
    :param percent: integer value for the threshold (e.g., 90 for 90%).
    :return: sim_val_cols: list of column names meeting the criteria.
    """
    sim_val_cols = []
    for col in df.columns:
        # Calculate value counts and their percentages
        # value_counts(normalize=True) gives proportions, multiply by 100 for percentage
        value_counts = df[col].value_counts(normalize=True) * 100

        # Check if there are any values in the column
        if not value_counts.empty:
            # Get the percentage of the most frequent value
            most_frequent_percent = value_counts.iloc[0]

            # Check if the most frequent value's percentage is > percent AND
            # if there are more than 2 unique values (to exclude binary and single-value columns)
            # len(value_counts.index) gives the number of unique values
            if most_frequent_percent > percent: #and len(value_counts.index) > 2:
                sim_val_cols.append(col)

    # Print the total count after the loop finishes
    print(f"Total columns found with a single value sharing > {percent}% : {len(sim_val_cols)}")

    return sim_val_cols

similar_cols = get_similar_value_cols(train_)
similar_cols_test = get_similar_value_cols(test_)
#print(similar_cols)
# Out:
# Total columns found with a single value sharing > 90% : 154
# Total columns found with a single value sharing > 90% : 154

# %%
train_=train_.drop(columns=similar_cols)
test_=test_.drop(columns=similar_cols) # same colum from each train and test are dropped

# %%
categorical_threshold = 20
def cat_num(df):
    unique_counts = df.nunique()
    # Identify categorical columns
    categorical_cols = unique_counts[unique_counts <= categorical_threshold].index.tolist()
    
    # Identify numerical/continuous columns
    # These are the columns where the unique count is GREATER than the threshold.
    numerical_cols = unique_counts[unique_counts > categorical_threshold].index.tolist()
    
    #len(categorical_cols),len(numerical_cols)
    df_num = df[numerical_cols]
    df_cat = df[categorical_cols]
    return df_num,df_cat

train_1_num,train_1_cat=cat_num(train_)
test_1_num,test_1_cat=cat_num(test_)

# %%
train_1_num
# Out:
#         Feature_1  Feature_2     Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    18281.541667    18432.0   9409.650391   0.514708   0.011300   0.045369
# 1    20010.083333    20100.0   8303.049072   0.417707   0.014959   0.080294
# 2    27260.125000    27437.0  12189.649414   0.447160   0.011428   0.046402
# 3    41938.125000    42138.0  17866.433594   0.426019   0.009908   0.034878
# 4    41274.125000    41439.0  14315.041992   0.346828   0.013596   0.065680
# ..            ...        ...           ...        ...        ...        ...
# 310  46787.916667    47002.0  18052.070312   0.385828   0.010883   0.042086
# 311   8420.354167     8493.0   4292.039795   0.510004   0.016911   0.101797
# 312  37262.750000    37407.0  13950.793945   0.374390   0.012759   0.057837
# 313  25081.833333    25251.0  11689.275391   0.466045   0.011197   0.044546
# 314  52925.083333    53137.0  19790.341797   0.373931   0.010725   0.040871
#
#      Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_3227  \
# 0     2.803803   0.356658   1.803803  564.936250  ...      0.003820
# 1     2.338398   0.429532   1.338398   31.291507  ...      0.003124
# 2     2.782842   0.359345   1.782842   11.965643  ...      0.003357
# 3     3.060655   0.326727   2.060655    8.966286  ...      0.003292
# 4     2.478506   0.403469   1.478506   34.898671  ...      0.002901
# ..         ...        ...        ...         ...  ...           ...
# 310   2.874885   0.347840   1.874885   23.499143  ...      0.003033
# 311   2.145061   0.466555   1.145061   25.293867  ...      0.003948
# 312   2.585819   0.386725   1.585819   37.474634  ...      0.002889
# 313   2.820962   0.354489   1.820962   18.321132  ...      0.003616
# 314   2.903096   0.344460   1.903096   35.784277  ...      0.003111
#
#      Feature_3228  Feature_3229  Feature_3230  Feature_3231  Feature_3233  \
# 0        0.003820    382.968383    382.968383        2214.0    136.625113
# 1        0.003124    452.986164    452.986164        2548.5    232.564022
# 2        0.003357    419.781765    419.781765        3400.0    233.593529
# 3        0.003292    439.023968    439.023968        5424.0    427.429572
# 4        0.002901    485.209184    485.209184        5096.0    726.731554
# ..            ...           ...           ...           ...           ...
# 310      0.003033    466.276055    466.276055        6064.0    585.547823
# 311      0.003948    383.044821    383.044821         987.0     69.155790
# 312      0.002889    469.005263    469.005263        4940.0    505.566802
# 313      0.003616    403.597826    403.597826        2944.0    215.172554
# 314      0.003111    479.596830    479.596830        6625.0    789.191094
#
#      Feature_3234  Feature_3236  Feature_3237  Feature_3238
# 0        0.061710     28.154838      4.174959      0.061710
# 1        0.090548     27.934229      3.931950      0.090548
# 2        0.068704     27.904807      4.085035      0.068704
# 3        0.078803     27.870588      4.011726      0.078803
# 4        0.142608     28.846909      3.571352      0.142608
# ..            ...           ...           ...           ...
# 310      0.096561     28.787507      3.894684      0.096561
# 311      0.070369     29.625473      4.098452      0.070369
# 312      0.102341     26.865256      3.815115      0.102341
# 313      0.073089     29.180584      4.055504      0.073089
# 314      0.119123     29.689509      3.765621      0.119123
#
# [315 rows x 3065 columns]

# %%
def fill_missing_values(num_df, cat_df):
    """
    Fills missing values in numerical columns with mean and
    in categorical columns with mode.
    
    Parameters:
    - num_df: DataFrame containing numerical columns
    - cat_df: DataFrame containing categorical columns
    
    Returns:
    - cleaned_df: Combined DataFrame with missing values filled
    """
    # Fill numerical columns
    for col in num_df.columns:
        if num_df[col].isna().any():
            num_df[col] = num_df[col].fillna(num_df[col].mean())
    
    # Fill categorical columns
    for col in cat_df.columns:
        if cat_df[col].isna().any():
            cat_df[col] = cat_df[col].fillna(cat_df[col].mode()[0])
    
    # Combine back numerical and categorical DataFrames
    cleaned_df = pd.concat([num_df, cat_df], axis=1)
    
    return cleaned_df

# For training set
train_1_cleaned = fill_missing_values(train_1_num, train_1_cat)

# For test set
test_1_cleaned = fill_missing_values(test_1_num, test_1_cat)
# Out:
# /var/folders/kb/f1k4_th17h992yvkrm2v50d40000gn/T/ipykernel_66248/3095335783.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_df[col] = num_df[col].fillna(num_df[col].mean())
# /var/folders/kb/f1k4_th17h992yvkrm2v50d40000gn/T/ipykernel_66248/3095335783.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df[col] = cat_df[col].fillna(cat_df[col].mode()[0])
# /var/folders/kb/f1k4_th17h992yvkrm2v50d40000gn/T/ipykernel_66248/3095335783.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_df[col] = num_df[col].fillna(num_df[col].mean())
# /var/folders/kb/f1k4_th17h992yvkrm2v50d40000gn/T/ipykernel_66248/3095335783.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df[col] = cat_df[col].fillna(cat_df[col].mode()[0])

# %%
missing = train_1_cleaned.isnull().sum()
print(missing[missing > 0])
# Out:
# Series([], dtype: int64)

# %%
# missin_cols=['Feature_1712',
#     'Feature_1713','Feature_1714','Feature_1715','Feature_1716','Feature_1717','Feature_1718','Feature_1719','Feature_1721','Feature_1722',
#     'Feature_1723','Feature_1724','Feature_1725','Feature_1726','Feature_1727','Feature_1728','Feature_1729','Feature_1730','Feature_1731',
#     'Feature_1733','CLASS']
# Compute correlation matrix for selected columns
corr_matrix = train[missin_cols].corr()

# Plot heatmap
plt.figure(figsize=(16, 14))
sns.heatmap(corr_matrix, annot=True, cmap='viridis', linewidths=0.5)
plt.title("Correlation Heatmap of Selected Columns")
plt.show()

# %%
missing = test_.isnull().sum()
print(missing[missing > 0])
# Out:
# Feature_1712    49
# Feature_1713    49
# Feature_1714    49
# Feature_1715    49
# Feature_1719    49
# Feature_1722    49
# Feature_1724    49
# Feature_1725    49
# Feature_1726    49
# Feature_1727    49
# Feature_1728    49
# Feature_1729    49
# Feature_1730    49
# Feature_1731    49
# Feature_1733    49
# dtype: int64

# %%
train_
# Out:
#         Feature_1  Feature_2     Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    18281.541667    18432.0   9409.650391   0.514708   0.011300   0.045369
# 1    20010.083333    20100.0   8303.049072   0.417707   0.014959   0.080294
# 2    27260.125000    27437.0  12189.649414   0.447160   0.011428   0.046402
# 3    41938.125000    42138.0  17866.433594   0.426019   0.009908   0.034878
# 4    41274.125000    41439.0  14315.041992   0.346828   0.013596   0.065680
# ..            ...        ...           ...        ...        ...        ...
# 310  46787.916667    47002.0  18052.070312   0.385828   0.010883   0.042086
# 311   8420.354167     8493.0   4292.039795   0.510004   0.016911   0.101797
# 312  37262.750000    37407.0  13950.793945   0.374390   0.012759   0.057837
# 313  25081.833333    25251.0  11689.275391   0.466045   0.011197   0.044546
# 314  52925.083333    53137.0  19790.341797   0.373931   0.010725   0.040871
#
#      Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_3227  \
# 0     2.803803   0.356658   1.803803  564.936250  ...      0.003820
# 1     2.338398   0.429532   1.338398   31.291507  ...      0.003124
# 2     2.782842   0.359345   1.782842   11.965643  ...      0.003357
# 3     3.060655   0.326727   2.060655    8.966286  ...      0.003292
# 4     2.478506   0.403469   1.478506   34.898671  ...      0.002901
# ..         ...        ...        ...         ...  ...           ...
# 310   2.874885   0.347840   1.874885   23.499143  ...      0.003033
# 311   2.145061   0.466555   1.145061   25.293867  ...      0.003948
# 312   2.585819   0.386725   1.585819   37.474634  ...      0.002889
# 313   2.820962   0.354489   1.820962   18.321132  ...      0.003616
# 314   2.903096   0.344460   1.903096   35.784277  ...      0.003111
#
#      Feature_3228  Feature_3229  Feature_3230  Feature_3231  Feature_3233  \
# 0        0.003820    382.968383    382.968383        2214.0    136.625113
# 1        0.003124    452.986164    452.986164        2548.5    232.564022
# 2        0.003357    419.781765    419.781765        3400.0    233.593529
# 3        0.003292    439.023968    439.023968        5424.0    427.429572
# 4        0.002901    485.209184    485.209184        5096.0    726.731554
# ..            ...           ...           ...           ...           ...
# 310      0.003033    466.276055    466.276055        6064.0    585.547823
# 311      0.003948    383.044821    383.044821         987.0     69.155790
# 312      0.002889    469.005263    469.005263        4940.0    505.566802
# 313      0.003616    403.597826    403.597826        2944.0    215.172554
# 314      0.003111    479.596830    479.596830        6625.0    789.191094
#
#      Feature_3234  Feature_3236  Feature_3237  Feature_3238
# 0        0.061710     28.154838      4.174959      0.061710
# 1        0.090548     27.934229      3.931950      0.090548
# 2        0.068704     27.904807      4.085035      0.068704
# 3        0.078803     27.870588      4.011726      0.078803
# 4        0.142608     28.846909      3.571352      0.142608
# ..            ...           ...           ...           ...
# 310      0.096561     28.787507      3.894684      0.096561
# 311      0.070369     29.625473      4.098452      0.070369
# 312      0.102341     26.865256      3.815115      0.102341
# 313      0.073089     29.180584      4.055504      0.073089
# 314      0.119123     29.689509      3.765621      0.119123
#
# [315 rows x 3084 columns]

# %%
import numpy as np
#print(np.isinf(train_1).any().any())
#print(np.isinf(test_).any().any())

# %%
#print(np.isinf(train_1).any().any())
import numpy as np
def fill_inf(df):
# Example: Create a boolean DataFrame where True = inf or -inf
    inf_mask = np.isinf(df)
    inf_positions = [(row_idx, col) for row_idx, row in inf_mask.iterrows() for col in df.columns if row[col]]
    #print(inf_positions)
    
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    df.fillna(df.mean(), inplace=True)
    return df
    
    # inf_mask_test=np.isinf(test_1_cleaned)
    # inf_positions_test = [(row_idx, col) for row_idx, row in inf_mask_test.iterrows() for col in test_1_cleaned.columns if row[col]]
    # test_1_cleaned.replace([np.inf, -np.inf], np.nan, inplace=True)
    # test_1_cleaned.fillna(test_1_cleaned.mean(), inplace=True)

# %%
train_1_cleaned_inf=fill_inf(train_1_cleaned)
test_1_cleaned_inf=fill_inf(test_1_cleaned)

# %%
train_1_cleaned_inf
# Out:
#         Feature_1  Feature_2     Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    18281.541667    18432.0   9409.650391   0.514708   0.011300   0.045369
# 1    20010.083333    20100.0   8303.049072   0.417707   0.014959   0.080294
# 2    27260.125000    27437.0  12189.649414   0.447160   0.011428   0.046402
# 3    41938.125000    42138.0  17866.433594   0.426019   0.009908   0.034878
# 4    41274.125000    41439.0  14315.041992   0.346828   0.013596   0.065680
# ..            ...        ...           ...        ...        ...        ...
# 310  46787.916667    47002.0  18052.070312   0.385828   0.010883   0.042086
# 311   8420.354167     8493.0   4292.039795   0.510004   0.016911   0.101797
# 312  37262.750000    37407.0  13950.793945   0.374390   0.012759   0.057837
# 313  25081.833333    25251.0  11689.275391   0.466045   0.011197   0.044546
# 314  52925.083333    53137.0  19790.341797   0.373931   0.010725   0.040871
#
#      Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_1722  \
# 0     2.803803   0.356658   1.803803  564.936250  ...           0.0
# 1     2.338398   0.429532   1.338398   31.291507  ...           0.0
# 2     2.782842   0.359345   1.782842   11.965643  ...           1.0
# 3     3.060655   0.326727   2.060655    8.966286  ...           1.0
# 4     2.478506   0.403469   1.478506   34.898671  ...           0.0
# ..         ...        ...        ...         ...  ...           ...
# 310   2.874885   0.347840   1.874885   23.499143  ...           0.0
# 311   2.145061   0.466555   1.145061   25.293867  ...           0.0
# 312   2.585819   0.386725   1.585819   37.474634  ...           0.0
# 313   2.820962   0.354489   1.820962   18.321132  ...           0.0
# 314   2.903096   0.344460   1.903096   35.784277  ...           1.0
#
#      Feature_1728  Feature_2497  Feature_2625  Feature_2658  Feature_2661  \
# 0        0.000000           1.0           1.0           1.0  0.000000e+00
# 1        0.000000           1.0           1.0           1.0  0.000000e+00
# 2        0.333333           1.0           1.0           1.0  0.000000e+00
# 3        0.333333           1.4           1.0           1.0  0.000000e+00
# 4        0.000000           1.0           1.0           1.0  0.000000e+00
# ..            ...           ...           ...           ...           ...
# 310      0.000000           1.0           1.0           1.0  0.000000e+00
# 311      0.000000           1.0           1.4           1.0  0.000000e+00
# 312      0.000000           1.0           1.0           1.0  0.000000e+00
# 313      0.000000           1.0           1.0           1.0  1.232595e-32
# 314      0.333333           1.0           1.0           1.0  0.000000e+00
#
#      Feature_2722  Feature_2850  Feature_2853  Feature_2881
# 0             1.0           1.0  0.000000e+00           2.0
# 1             1.0           1.0  0.000000e+00           1.5
# 2             1.0           1.0  0.000000e+00           3.0
# 3             1.0           1.0  0.000000e+00           4.0
# 4             1.0           1.0  4.930381e-32           4.0
# ..            ...           ...           ...           ...
# 310           1.0           1.0  1.232595e-32           1.0
# 311           1.0           1.0  0.000000e+00           3.0
# 312           1.0           1.0  0.000000e+00           1.0
# 313           1.0           1.0  0.000000e+00           1.0
# 314           1.0           1.0  0.000000e+00           3.0
#
# [315 rows x 3084 columns]

# %%
def cap_outliers(df):
    df_capped = df.copy()  # Avoid modifying original data
    
    # Iterate over numeric columns
    for col in df_capped:
        Q1 = df_capped[col].quantile(0.25)
        Q3 = df_capped[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Cap the values
        df_capped[col] = np.where(df_capped[col] < lower_bound, lower_bound, df_capped[col])
        df_capped[col] = np.where(df_capped[col] > upper_bound, upper_bound, df_capped[col])
    
    return df_capped

train_1_num,train_1_cat_n=cat_num(train_1_cleaned_inf)
test_1_num,test_1_cat_n=cat_num(test_1_cleaned_inf)
# Apply to your DataFrame
train_1_num_capped = cap_outliers(train_1_num)
test_1_num_capped = cap_outliers(test_1_num)

# Check capped data
# print(train_1_capped.describe())


# If you want to recombine:
train_1_capped = pd.concat([train_1_num_capped, train_1_cat_n], axis=1)
test_1_capped = pd.concat([test_1_num_capped, test_1_cat_n], axis=1)


# Check results
#print(train_1_capped.head())

# %%
smote = SMOTE(random_state=42)
y_train_1=train['CLASS']
train_1, y_train = smote.fit_resample(train_1_cleaned_inf, y_train_1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Number of columns you want to visualize
n_cols_to_plot = 5

# Select random numeric columns
numeric_cols = train_1.select_dtypes(include=[np.number]).columns
random_cols = np.random.choice(numeric_cols, size=n_cols_to_plot, replace=False)

# Plot individual histograms for each selected column
for col in random_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(train_1[col].dropna(), bins=30, kde=True, color='blue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
# Number of columns you want to select and plot
n_cols_to_plot = 5

# Randomly select columns (make sure only numeric columns are selected for boxplots)
numeric_cols = train_1.select_dtypes(include=[np.number]).columns
random_cols = np.random.choice(numeric_cols, size=n_cols_to_plot, replace=False)

# Plot individual box plots for each selected column
for col in random_cols:
    plt.figure(figsize=(6, 4))
    plt.boxplot(train_1[col].dropna(), vert=True, patch_artist=True)
    plt.title(f'Boxplot of {col}')
    plt.ylabel(col)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# Clearly distribution of most of the columns is skewed. So I am goint to cap outlier

# %%
train_1
# Out:
#         Feature_1     Feature_2     Feature_3  Feature_4  Feature_5  \
# 0    18281.541667  18432.000000   9409.650391   0.514708   0.011300
# 1    20010.083333  20100.000000   8303.049072   0.417707   0.014959
# 2    27260.125000  27437.000000  12189.649414   0.447160   0.011428
# 3    41938.125000  42138.000000  17866.433594   0.426019   0.009908
# 4    41274.125000  41439.000000  14315.041992   0.346828   0.013596
# ..            ...           ...           ...        ...        ...
# 377  29883.508618  29990.938827   9759.820009   0.328656   0.017916
# 378  27674.341957  27855.272277  12697.243849   0.458922   0.010920
# 379  52980.616381  53149.271835  17628.247557   0.332309   0.012847
# 380  28291.408620  28432.784104  11169.452042   0.393556   0.013681
# 381  45183.658250  45406.150093  18990.403717   0.419740   0.009797
#
#      Feature_6  Feature_7  Feature_8  Feature_9  Feature_10  ...  \
# 0     0.045369   2.803803   0.356658   1.803803  564.936250  ...
# 1     0.080294   2.338398   0.429532   1.338398   31.291507  ...
# 2     0.046402   2.782842   0.359345   1.782842   11.965643  ...
# 3     0.034878   3.060655   0.326727   2.060655    8.966286  ...
# 4     0.065680   2.478506   0.403469   1.478506   34.898671  ...
# ..         ...        ...        ...        ...         ...  ...
# 377   0.117365   2.103987   0.483205   1.103987    8.462754  ...
# 378   0.042416   2.870166   0.348580   1.870166  144.419474  ...
# 379   0.058845   2.579530   0.388353   1.579530   86.182709  ...
# 380   0.067004   2.479976   0.404791   1.479976   31.086428  ...
# 381   0.034295   3.092177   0.324108   2.092177  136.920143  ...
#
#      Feature_1722  Feature_1728  Feature_2497  Feature_2625  Feature_2658  \
# 0         0.00000      0.000000      1.000000           1.0           1.0
# 1         0.00000      0.000000      1.000000           1.0           1.0
# 2         1.00000      0.333333      1.000000           1.0           1.0
# 3         1.00000      0.333333      1.400000           1.0           1.0
# 4         0.00000      0.000000      1.000000           1.0           1.0
# ..            ...           ...           ...           ...           ...
# 377       0.40406      0.134687      1.000000           1.0           1.0
# 378       0.00000      0.000000      1.244397           1.0           1.0
# 379       0.00000      0.000000      1.000000           1.0           1.0
# 380       0.00000      0.000000      1.000000           1.0           1.0
# 381       0.00000      0.000000      1.000000           1.0           1.0
#
#      Feature_2661  Feature_2722  Feature_2850  Feature_2853  Feature_2881
# 0    0.000000e+00           1.0           1.0  0.000000e+00      2.000000
# 1    0.000000e+00           1.0           1.0  0.000000e+00      1.500000
# 2    0.000000e+00           1.0           1.0  0.000000e+00      3.000000
# 3    0.000000e+00           1.0           1.0  0.000000e+00      4.000000
# 4    0.000000e+00           1.0           1.0  4.930381e-32      4.000000
# ..            ...           ...           ...           ...           ...
# 377  7.345525e-33           1.0           1.0  1.444082e-32      2.212181
# 378  0.000000e+00           1.0           1.0  4.518648e-33      4.366596
# 379  0.000000e+00           1.0           1.0  1.074158e-32      1.000000
# 380  0.000000e+00           1.0           1.0  9.679714e-33      1.588984
# 381  0.000000e+00           1.0           1.0  0.000000e+00      1.000000
#
# [382 rows x 3084 columns]

# %%
import numpy as np

def log_transform_df(df, cols=None):
    """
    Apply natural log transform to selected numeric columns of a DataFrame.

    Parameters:
    - df: pandas DataFrame
    - cols: list of column names to apply log transform.
            If None, it applies to all numeric columns.

    Returns:
    - log_df: DataFrame with log-transformed columns
    """
    log_df = df.copy()
    
    # If no specific columns, use all numeric columns
    if cols is None:
        cols = df.select_dtypes(include=[np.number]).columns.tolist()
    
    for col in cols:
        # Use np.log1p to handle zeros (log(1 + x)) safely
        log_df[col] = np.log1p(log_df[col])
    
    return log_df

log_train_1=log_transform_df(train_1_num_capped)
log_test_1=log_transform_df(test_1_num_capped)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# log_train_1=fill_inf(log_train_1)
# log_test_1=fill_inf(log_test_1)

# %%
# train_1_num_capped[train_1_num_capped <= 0] = 1e-9
# test_1_num_capped[test_1_num_capped <= 0] = 1e-9
# train_1_capped = pd.concat([train_1_num_capped, train_1_cat], axis=1)
# test_1_capped = pd.concat([test_1_num_capped, test_1_cat], axis=1)
# log_train_1_t=pd.concat([log_train_1, train_1_cat], axis=1)
# log_test_1_t=pd.concat([log_test_1, train_1_cat], axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Scale the data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(train_1)

# Run t-SNE
tsne = TSNE(n_components=3, random_state=42)
df_tsne = tsne.fit_transform(train_1)

# Plot
plt.scatter(df_tsne[:, 0], df_tsne[:, 1])
plt.title("t-SNE after MinMaxScaler Scaling")
plt.show()

# %%
# from sklearn.feature_selection import RFECV

# rfecv = RFECV(estimator=logreg, step=1, cv=5, scoring='accuracy')

# rfecv = rfecv.fit(X_train, y_train)

# %%
negative_columns = train_exp.columns[(train_exp < 0).any()].tolist()

#print("Columns with negative values:", negative_columns)
# Count of negative values for each column
neg_counts = train_exp[negative_columns].apply(lambda x: (x < 0).sum())

print("Number of negative values in each column:")
print(neg_counts)
# Out:
# Number of negative values in each column:
# Feature_27       69
# Feature_55       17
# Feature_57       68
# Feature_59      216
# Feature_60      151
# Feature_61       29
# Feature_62      195
# Feature_63      188
# Feature_71       69
# Feature_95      244
# Feature_96      149
# Feature_114     345
# Feature_137     212
# Feature_237     216
# Feature_239     379
# Feature_1678     47
# Feature_1679    311
# Feature_1714      2
# Feature_1715     63
# Feature_1731    382
# Feature_1756     43
# Feature_1758    382
# Feature_1856     41
# Feature_1858    382
# Feature_1881     24
# Feature_1883    382
# Feature_1906      4
# Feature_1908    230
# dtype: int64

# %%
train[train['CLASS'] == 1]['Feature_1908'].plot(kind='kde',label='1')
train[train['CLASS'] == 0]['Feature_1908'].plot(kind='kde',label='0')

plt.legend()
plt.show()
"""
Label 1 have higher chance of occurance in range -2 to 0.5 and label 0 have high chance of occurance in range 0.5 
to 2.
"""

# %%
sns.scatterplot(
    x='Feature_1',
    y='Feature_4',
    hue='CLASS',
    #palette='coolwarm',
    data=train,
    s=30
)
# Out:
# <Axes: xlabel='Feature_1', ylabel='Feature_4'>

# %%
org_exp
# Out:
#         Feature_1  Feature_4  Feature_5  Feature_10  Feature_11  Feature_13  \
# 0    18281.541667   0.514708   0.011300   87.989584  179.125654   44.140704
# 1    20010.083333   0.417707   0.014959   31.291507  122.447882   27.150254
# 2    27260.125000   0.447160   0.011428   11.965643  241.904940   47.572298
# 3    41938.125000   0.426019   0.009908    8.966286  226.260911   34.835854
# 4    41274.125000   0.346828   0.013596   34.898671  208.619270   45.788460
# ..            ...        ...        ...         ...         ...         ...
# 310  46787.916667   0.385828   0.010883   23.499143  278.217541   48.569993
# 311   8420.354167   0.510004   0.016911   25.293867   93.618836   18.100903
# 312  37262.750000   0.374390   0.012759   37.474634  202.610464   38.141866
# 313  25081.833333   0.466045   0.011197   18.321132  204.320826   47.209078
# 314  52925.083333   0.373931   0.010725   35.784277  215.596846   52.378874
#
#      Feature_14  Feature_15  Feature_16  Feature_17  ...  Feature_115  \
# 0     18.149861    0.216274    0.088928    0.044369  ...         17.0
# 1     14.165947    0.207880    0.108412    0.094739  ...          9.0
# 2     22.613842    0.161702    0.076866    0.051804  ...          1.0
# 3     29.188142    0.135663    0.113669    0.094232  ...          1.0
# 4     20.180269    0.175847    0.077501    0.083674  ...         18.0
# ..          ...         ...         ...         ...  ...          ...
# 310   21.849623    0.149795    0.067387    0.067515  ...         17.0
# 311   13.007549    0.181568    0.131103    0.143963  ...         17.0
# 312   28.135131    0.156558    0.115484    0.099563  ...         18.0
# 313   25.232333    0.194147    0.103768    0.061471  ...         17.0
# 314   31.852198    0.206894    0.125815    0.053853  ...         18.0
#
#      Feature_1719  Feature_1722  Feature_2497  Feature_2625  Feature_2658  \
# 0             1.0           0.0           1.0           1.0           1.0
# 1             2.0           0.0           1.0           1.0           1.0
# 2             2.0           1.0           1.0           1.0           1.0
# 3             2.0           1.0           1.4           1.0           1.0
# 4             2.0           0.0           1.0           1.0           1.0
# ..            ...           ...           ...           ...           ...
# 310           2.0           0.0           1.0           1.0           1.0
# 311           1.0           0.0           1.0           1.4           1.0
# 312           2.0           0.0           1.0           1.0           1.0
# 313           2.0           0.0           1.0           1.0           1.0
# 314           2.0           1.0           1.0           1.0           1.0
#
#      Feature_2722  Feature_2850  Feature_2853  Feature_2881
# 0             1.0           1.0  0.000000e+00           2.0
# 1             1.0           1.0  0.000000e+00           1.5
# 2             1.0           1.0  0.000000e+00           3.0
# 3             1.0           1.0  0.000000e+00           4.0
# 4             1.0           1.0  4.930381e-32           4.0
# ..            ...           ...           ...           ...
# 310           1.0           1.0  1.232595e-32           1.0
# 311           1.0           1.0  0.000000e+00           3.0
# 312           1.0           1.0  0.000000e+00           1.0
# 313           1.0           1.0  0.000000e+00           1.0
# 314           1.0           1.0  0.000000e+00           3.0
#
# [315 rows x 717 columns]

# %%
# Remove features with correlation > 0.95
def rem_high_corr(df):
    corr_matrix = df.corr().abs()
    upper = corr_matrix.where(
        np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
    #df.drop(columns=to_drop, inplace=True)
    #df_1=df.drop(columns=to_drop)
    return to_drop
column_drop=rem_high_corr(train_1_capped)
#train_exp=rem_high_corr(train_1_capped)
train_1.drop(columns=column_drop,inplace=True)
test_1_capped.drop(columns=column_drop,inplace=True)
#test_exp=rem_high_corr(test_1_capped)

# %%
test_1_capped
# Out:
#        Feature_1  Feature_4  Feature_5  Feature_10  Feature_11  Feature_13  \
# 0   15385.458333   0.413973   0.015765    3.165713  136.849655   17.482995
# 1   19539.729167   0.417849   0.014973   11.257600  137.432916   26.914001
# 2   34867.125000   0.412507   0.011404   68.831843  247.727673   39.253779
# 3   46112.083333   0.358098   0.012261    8.614636  247.103217   45.856962
# 4   37229.000000   0.348699   0.014201   10.869511  215.216170   28.984571
# ..           ...        ...        ...         ...         ...         ...
# 95  41560.708333   0.385151   0.011578   26.477994  208.252251   30.902906
# 96  47127.500000   0.331394   0.013623   23.197246  218.158199   35.586120
# 97  44099.625000   0.392559   0.010923   26.133394  286.567619   45.846735
# 98  29193.833333   0.403239   0.012895   16.133637  222.139596   44.890517
# 99  53834.083333   0.325854   0.013073   15.892644  235.110612   52.228202
#
#     Feature_14  Feature_15  Feature_16  Feature_17  ...  Feature_2725  \
# 0    14.444362    0.134877    0.110311    0.094150  ...  6.162976e-33
# 1    15.199072    0.191581    0.105430    0.073035  ...  0.000000e+00
# 2    22.395359    0.123889    0.070682    0.069925  ...  0.000000e+00
# 3    21.074495    0.158816    0.072987    0.102096  ...  0.000000e+00
# 4    27.545766    0.118606    0.112718    0.093368  ...  0.000000e+00
# ..         ...         ...         ...         ...  ...           ...
# 95   25.962195    0.128404    0.107875    0.116730  ...  0.000000e+00
# 96   25.525543    0.143170    0.102694    0.119030  ...  0.000000e+00
# 97   19.225935    0.136717    0.057333    0.051222  ...  0.000000e+00
# 98   14.535200    0.162425    0.052592    0.087128  ...  0.000000e+00
# 99   33.073415    0.178509    0.113041    0.090933  ...  0.000000e+00
#
#     Feature_2737  Feature_2775  Feature_2776  Feature_2786  Feature_2789  \
# 0            3.0           1.0           1.0           1.0  6.162976e-33
# 1            2.5           1.0           1.0           1.0  0.000000e+00
# 2            7.0           1.0           1.0           1.0  0.000000e+00
# 3            4.0           1.0           1.0           1.0  0.000000e+00
# 4            4.0           1.0           1.0           1.0  0.000000e+00
# ..           ...           ...           ...           ...           ...
# 95           4.0           1.0           1.0           1.0  0.000000e+00
# 96           8.0           1.0           1.0           1.0  0.000000e+00
# 97           6.0           1.0           1.0           1.0  0.000000e+00
# 98           3.0           1.0           1.0           1.0  0.000000e+00
# 99           3.0           1.0           1.0           1.0  0.000000e+00
#
#     Feature_2850  Feature_2853  Feature_2865  Feature_2881
# 0            1.0  0.000000e+00           3.0           2.0
# 1            1.0  0.000000e+00           3.0           1.0
# 2            1.0  0.000000e+00           7.0           4.0
# 3            1.0  0.000000e+00           3.0           1.0
# 4            1.0  0.000000e+00           3.0           1.0
# ..           ...           ...           ...           ...
# 95           1.0  0.000000e+00           4.0           1.0
# 96           1.0  0.000000e+00           6.0           4.0
# 97           1.0  1.232595e-32           6.0           4.0
# 98           1.0  0.000000e+00           3.0           1.0
# 99           1.0  0.000000e+00           3.0           1.0
#
# [100 rows x 717 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, adjusted_rand_score

# Let's say we suspect 2 clusters for binary classification
kmeans = KMeans(n_clusters=2, random_state=42)

# Fit on train data
kmeans.fit(X_train)

# Predict cluster labels for both train and test sets
train_clusters = kmeans.predict(X_train)
test_clusters = kmeans.predict(X_test)

# Silhouette Score (how well clusters are separated)
train_silhouette = silhouette_score(X_train, train_clusters)
print("Train Silhouette Score:", train_silhouette)

# If you want to see how clusters align with actual labels (supervised metric)
from sklearn.metrics import confusion_matrix
print("Train Confusion Matrix:\n", confusion_matrix(y_train, train_clusters))
print("Test Confusion Matrix:\n", confusion_matrix(y_test, test_clusters))

# Or Adjusted Rand Index (for clustering agreement with true labels)
ari_train = adjusted_rand_score(y_train, train_clusters)
print("Train Adjusted Rand Index:", ari_train)

from sklearn.cluster import DBSCAN

# DBSCAN hyperparameters
dbscan = DBSCAN(eps=2.0, min_samples=5)  # tweak eps!

# Fit on train data
dbscan.fit(X_train)

# Predict cluster labels (-1 = noise)
train_dbscan_labels = dbscan.labels_

# Number of clusters found (excluding noise)
n_clusters_ = len(set(train_dbscan_labels)) - (1 if -1 in train_dbscan_labels else 0)
print("Number of clusters found by DBSCAN:", n_clusters_)

# Silhouette score for DBSCAN
if n_clusters_ > 1:
    dbscan_silhouette = silhouette_score(X_train, train_dbscan_labels)
    print("DBSCAN Train Silhouette Score:", dbscan_silhouette)
else:
    print("DBSCAN did not find multiple clusters for silhouette scoring.")

# Check how well they align with actual labels
print("Train Confusion Matrix:\n", confusion_matrix(y_train, train_dbscan_labels))

import matplotlib.pyplot as plt

# Let's plot the **first two PCA components** for easy visualization
X_train_plot = X_train[:, :2]  # use first two PCA components
X_test_plot = X_test[:, :2]

# 🎨 Plot KMeans Clusters
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_train_plot[:, 0], X_train_plot[:, 1], c=train_clusters, cmap='viridis', s=30)
plt.title('KMeans Clusters (Train)')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.colorbar(label='Cluster Label')

# 🎨 Plot DBSCAN Clusters
plt.subplot(1, 2, 2)
plt.scatter(X_train_plot[:, 0], X_train_plot[:, 1], c=train_dbscan_labels, cmap='rainbow', s=30)
plt.title('DBSCAN Clusters (Train)')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.colorbar(label='Cluster Label')

plt.tight_layout()
# Out:
# Train Silhouette Score: 0.15392102897584073
# Train Confusion Matrix:
#  [[ 94  97]
#  [101  90]]
# Test Confusion Matrix:
#  [[28 30]
#  [26 16]]
# Train Adjusted Rand Index: -0.0012837237163412056
# Number of clusters found by DBSCAN: 0
# DBSCAN did not find multiple clusters for silhouette scoring.
# Train Confusion Matrix:
#  [[  0   0   0]
#  [191   0   0]
#  [191   0   0]]

# %%
plt.scatter(X_train_plot[:, 0], X_train_plot[:, 1], c=y_train, cmap='coolwarm', s=30)
plt.title('True Labels (Train)')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.colorbar(label='True Label')
plt.show()

# %%
n_cols = np.random.randint(10, 16)  # pick a random number between 10 and 15
target_col=train['CLASS']
random_cols = np.random.choice(train_exp.columns, n_cols, replace=False)
selected_cols = list(random_cols) 

print("Selected columns:\n", selected_cols)

# Subset the DataFrame
df_subset = train_1[selected_cols]
df_subset['CLASS']=target_col

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df_subset.corr(), annot=True, cmap='coolwarm')
plt.title(f"Heatmap of {n_cols} Randomly Selected Columns")
plt.show()
# Out:
# Selected columns:
#  ['Feature_1539', 'Feature_1738', 'Feature_2466', 'Feature_105', 'Feature_2185', 'Feature_2991', 'Feature_27', 'Feature_779', 'Feature_1096', 'Feature_240', 'Feature_2822', 'Feature_237']
# /var/folders/kb/f1k4_th17h992yvkrm2v50d40000gn/T/ipykernel_37454/4229203415.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['CLASS']=target_col

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
common_columns = train_1.columns.intersection(test_1_capped.columns)
X_alig = train_1[common_columns]
X_test_alig = test_1_capped[common_columns]
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_alig)
X_test_s = scaler.transform(X_test_alig)

pca = PCA(n_components=50)  # retain 95% variance
X_train_sel = pca.fit_transform(X_train_s)
X_test_sel=pca.transform(X_test_s)  
print(f"Reduced features: {X_train_sel.shape[1]}")
# Out:
# Reduced features: 50

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, classification_report

# Train-test split
X_train, X_test, y_test = X_train_sel,X_test_sel,test['CLASS']

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import GridSearchCV

# param_grid = {
#     'n_estimators': [50,200,300,400],
#     'max_depth': [10,15,20,30],
#     'min_samples_split': [2,5,10],
    
# }

# grid_search = GridSearchCV(
#     RandomForestClassifier(random_state=42),
#     param_grid,
#     cv=5,
#     scoring='accuracy',
#     n_jobs=-1
# )

# grid_search.fit(X_train_sel, y_train)
# print("Best parameters:", grid_search.best_params_)
# print("Best CV score:", grid_search.best_score_)

# best_model = grid_search.best_estimator_
# from sklearn.metrics import classification_report

# y_pred = best_model.predict(X_test_sel)
# print(classification_report(y_test, y_pred))
# y_prob = best_model.predict_proba(X_test_sel)[:, 1]  # probability for positive class

# # Metrics
# accuracy = accuracy_score(y_test, y_pred)
# auroc = roc_auc_score(y_test, y_prob)
# recall = recall_score(y_test, y_pred)  # Sensitivity / TPR

# # Confusion matrix to calculate specificity
# tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
# specificity = tn / (tn + fp)
# f1 = f1_score(y_test, y_pred)

# # Print metrics
# print(f"Accuracy: {accuracy:.4f}")
# print(f"AUROC: {auroc:.4f}")
# print(f"Sensitivity (Recall / TPR): {recall:.4f}")
# print(f"Specificity (TNR): {specificity:.4f}")
# print(f"F1-score: {f1:.4f}")
# Out:
# Best parameters: {'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 200}
# Best CV score: 0.707177033492823
#               precision    recall  f1-score   support
#
#            0       0.65      0.74      0.69        58
#            1       0.56      0.45      0.50        42
#
#     accuracy                           0.62       100
#    macro avg       0.61      0.60      0.60       100
# weighted avg       0.61      0.62      0.61       100
#
# Accuracy: 0.6200
# AUROC: 0.6687
# Sensitivity (Recall / TPR): 0.4524
# Specificity (TNR): 0.7414
# F1-score: 0.5000

# %%
joblib.dump(best_model, 'models/random_forest.pkl')
# Out:
# ['models/random_forest.pkl']

# %%
train_acc = best_model.score(X_train_sel, y_train)
test_acc = best_model.score(X_test_sel, y_test)
print(f"Train Accuracy: {train_acc}")
print(f"Test Accuracy: {test_acc}")
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.62

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, f1_score, confusion_matrix
# Random Forest
rf = RandomForestClassifier(max_depth= 10, min_samples_split=2,n_estimators=300, random_state=42)
rf.fit(X_train, y_train)

# Predictions
y_pred = rf.predict(X_test)


print("\nRandom Forest Classification Report:\n", classification_report(y_test, y_pred))
y_prob = rf.predict_proba(X_test)[:, 1]  # probability for positive class

# Metrics
accuracy = accuracy_score(y_test, y_pred)
auroc = roc_auc_score(y_test, y_prob)
recall = recall_score(y_test, y_pred)  # Sensitivity / TPR

# Confusion matrix to calculate specificity
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
specificity = tn / (tn + fp)
f1 = f1_score(y_test, y_pred)

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"AUROC: {auroc:.4f}")
print(f"Sensitivity (Recall / TPR): {recall:.4f}")
print(f"Specificity (TNR): {specificity:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71        58
#            1       0.60      0.57      0.59        42
#
#     accuracy                           0.66       100
#    macro avg       0.65      0.65      0.65       100
# weighted avg       0.66      0.66      0.66       100
#
# Accuracy: 0.6600
# AUROC: 0.6786
# Sensitivity (Recall / TPR): 0.5714
# Specificity (TNR): 0.7241
# F1-score: 0.5854

# %%
import joblib
joblib.dump(best_model, 'models/random_forest.pkl')
# Out:
# ['models/random_forest.pkl']

# %%
# import warnings
# warnings.filterwarnings('ignore')
# import xgboost as xgb
# from sklearn.model_selection import RandomizedSearchCV

# param_dist = {
#     'n_estimators': [100, 200, 300],
#     'max_depth': [3, 5, 7, 10],
#     'learning_rate': [0.01, 0.05, 0.1, 0.2],
#     'subsample': [0.6, 0.8, 1.0],
#     'colsample_bytree': [0.6, 0.8, 1.0],
#     'gamma': [0, 0.1, 0.2, 0.3],
#     'reg_alpha': [0, 0.01, 0.1],
#     'reg_lambda': [1, 1.5, 2],
# }
# clf = xgb.XGBClassifier(
#     objective='binary:logistic',  # for binary classification
#     eval_metric='logloss',        # logloss for binary classification
#     use_label_encoder=False,      # avoid warning
#     random_state=42,
#     n_jobs=-1                     # parallel jobs
# )

# random_search = RandomizedSearchCV(
#     clf,
#     param_distributions=param_dist,
#     n_iter=50,  # number of parameter settings to sample
#     scoring='accuracy',
#     cv=5,
#     verbose=1,
#     random_state=42
# )

# random_search.fit(X_train_scaled, y_train)
# print("Best parameters:", random_search.best_params_)
# print("Best CV accuracy:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[95], line 34
#      16 clf = xgb.XGBClassifier(
#      17     objective='binary:logistic',  # for binary classification
#      18     eval_metric='logloss',        # logloss for binary classification
#    (...)
#      21     n_jobs=-1                     # parallel jobs
#      22 )
#      24 random_search = RandomizedSearchCV(
#      25     clf,
#      26     param_distributions=param_dist,
#    (...)
#      31     random_state=42
#      32 )
# ---> 34 random_search.fit(X_train_scaled, y_train)
#      35 print("Best parameters:", random_search.best_params_)
#      36 print("Best CV accuracy:", random_search.best_score_)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1959, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1957 def _run_search(self, evaluate_candidates):
#    1958     """Search n_iter candidates from param_distributions"""
# -> 1959     evaluate_candidates(
#    1960         ParameterSampler(
#    1961             self.param_distributions, self.n_iter, random_state=self.random_state
#    1962         )
#    1963     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File /opt/anaconda3/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /opt/anaconda3/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/sklearn.py:1531, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1511 model, metric, params = self._configure_fit(xgb_model, params)
#    1512 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1513     missing=self.missing,
#    1514     X=X,
#    (...)
#    1528     feature_types=self.feature_types,
#    1529 )
# -> 1531 self._Booster = train(
#    1532     params,
#    1533     train_dmatrix,
#    1534     self.get_num_boosting_rounds(),
#    1535     evals=evals,
#    1536     early_stopping_rounds=self.early_stopping_rounds,
#    1537     evals_result=evals_result,
#    1538     obj=obj,
#    1539     custom_metric=metric,
#    1540     verbose_eval=verbose,
#    1541     xgb_model=model,
#    1542     callbacks=self.callbacks,
#    1543 )
#    1545 if not callable(self.objective):
#    1546     self.objective = params["objective"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# XGBoost

xgb = XGBClassifier(
    n_estimators=100,
        max_depth=12, 
        learning_rate=0.02, 
        subsample=0.8,
        colsample_bytree=0.4, 
        missing=-1, 
        eval_metric='logloss',
        # USE CPU
        #nthread=4,
        #tree_method='hist' 
        # USE GPU
        #tree_method='gpu_hist'
)
xgb.fit(X_train_scaled, y_train)

# Predictions
y_pred = xgb.predict(X_test_scaled)

# Evaluate

print("\nXGBoost Classification Report:\n", classification_report(y_test, y_pred))
y_prob = xgb.predict_proba(X_test_scaled)[:, 1]  # probability for positive class

# Metrics
accuracy = accuracy_score(y_test, y_pred)
auroc = roc_auc_score(y_test, y_prob)
recall = recall_score(y_test, y_pred)  # Sensitivity / TPR

# Confusion matrix to calculate specificity
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
specificity = tn / (tn + fp)
f1 = f1_score(y_test, y_pred)

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"AUROC: {auroc:.4f}")
print(f"Sensitivity (Recall / TPR): {recall:.4f}")
print(f"Specificity (TNR): {specificity:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# XGBoost Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72        58
#            1       0.61      0.48      0.53        42
#
#     accuracy                           0.65       100
#    macro avg       0.64      0.63      0.63       100
# weighted avg       0.64      0.65      0.64       100
#
# Accuracy: 0.6500
# AUROC: 0.6544
# Sensitivity (Recall / TPR): 0.4762
# Specificity (TNR): 0.7759
# F1-score: 0.5333

# %%
joblib.dump(xgb, 'models/xgboost.pkl')
# Out:
# ['models/xgboost.pkl']

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


def plot_roc_curve(y_true, y_scores, label='ROC Curve'):
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'{label} (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

plot_roc_curve(y_test, y_prob)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_s)
X_test_scaled = scaler.transform(X_test_s)
# Train logistic regression
logreg = LogisticRegression(solver='liblinear', random_state=42)
logreg.fit(X_train_scaled, y_train)

# Predictions
y_pred = logreg.predict(X_test_scaled)
y_prob = logreg.predict_proba(X_test_scaled)[:, 1]  # probability for positive class

# Metrics
accuracy = accuracy_score(y_test, y_pred)
auroc = roc_auc_score(y_test, y_prob)
recall = recall_score(y_test, y_pred)  # Sensitivity / TPR

# Confusion matrix to calculate specificity
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
specificity = tn / (tn + fp)
f1 = f1_score(y_test, y_pred)

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"AUROC: {auroc:.4f}")
print(f"Sensitivity (Recall / TPR): {recall:.4f}")
print(f"Specificity (TNR): {specificity:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.6900
# AUROC: 0.6773
# Sensitivity (Recall / TPR): 0.5476
# Specificity (TNR): 0.7931
# F1-score: 0.5974

# %%
joblib.dump(logreg, 'models/logreg_final_notebook.pkl')
# Out:
# ['models/logreg_final_notebook.pkl']

# %%
# def ensemble(x,X):
#     res1=rf.predict_proba(x)[:, 1]
#     res2=xgb.predict_proba(x)[:, 1]
#     res3=logreg.predict_proba(X)[:, 1]
#     y=0.4*res1+0.5*res3+0.1*res2
#     return y

# y_ens_pred=ensemble(X_test,X_test_scaled)
# y_ens_class = (y_ens_pred >= 0.6).astype(int)

# %%
# accuracy = accuracy_score(y_test, y_ens_class)
# auroc = roc_auc_score(y_test, y_ens_class)
# recall = recall_score(y_test, y_ens_class)  # Sensitivity / TPR

# # Confusion matrix to calculate specificity
# tn, fp, fn, tp = confusion_matrix(y_test, y_ens_class).ravel()
# specificity = tn / (tn + fp)
# f1 = f1_score(y_test, y_pred)

# # Print metrics
# print(f"Accuracy: {accuracy:.4f}")
# print(f"AUROC: {auroc:.4f}")
# print(f"Sensitivity (Recall / TPR): {recall:.4f}")
# print(f"Specificity (TNR): {specificity:.4f}")
# print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.6400
# AUROC: 0.6470
# Sensitivity (Recall / TPR): 0.6905
# Specificity (TNR): 0.6034
# F1-score: 0.5294

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# Base learners
estimators = [
    ('lrg', LogisticRegression(solver='liblinear', random_state=42)),
    ('rrf', RandomForestClassifier(max_depth= 10, min_samples_split=2,n_estimators=300, random_state=42))
]

# Meta-learner
meta_learner = LogisticRegression(random_state=42)

stacking_clf = StackingClassifier(
    estimators=estimators,
    final_estimator=meta_learner,
    cv=5
)

stacking_clf.fit(X_train_scaled, y_train)

y_pred = stacking_clf.predict(X_test_scaled)
y_pred_proba = stacking_clf.predict_proba(X_test_scaled)[:, 1]

accuracy = accuracy_score(y_test, y_pred)
auroc = roc_auc_score(y_test, y_pred_proba)
recall = recall_score(y_test, y_pred)  # Sensitivity / TPR

# Confusion matrix to calculate specificity
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
specificity = tn / (tn + fp)
f1 = f1_score(y_test, y_pred)

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"AUROC: {auroc:.4f}")
print(f"Sensitivity (Recall / TPR): {recall:.4f}")
print(f"Specificity (TNR): {specificity:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.6800
# AUROC: 0.6958
# Sensitivity (Recall / TPR): 0.5000
# Specificity (TNR): 0.8103
# F1-score: 0.5676

# %%
import joblib

# Save model
joblib.dump(stacking_clf, 'models/stacking_clf.pkl')

# Load model later
#rf_loaded = joblib.load('random_forest_model.pkl')
# Out:
# ['models/stacking_clf.pkl']
